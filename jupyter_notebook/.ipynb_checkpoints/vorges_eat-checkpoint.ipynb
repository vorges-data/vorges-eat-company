# %% [markdown]
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:200%;
#             text-align:center;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55 ;
#             overflow:hidden;
#             font-weight:700">Vorges Eat Data Analysis</div>

# %% [markdown]
# <a id=""></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">  <span style='color:#D2BA9E'>|</span> Contato</div>

# %% [markdown]
# Visite meu blog, será um prazer receber sua visita! 😃
#
# **Blog:**     www.vorges.com.br
#     <br>
# **Linkedin:** https://www.linkedin.com/in/viniciusleitedata/
#     <br>
# **Instagram:** https://instagram.com/vorges_data?igshid=YmMyMTA2M2Y=

# %% [markdown]
# <a id="000"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">  <span style='color:#D2BA9E'>|</span> Índice</div>

# %% [markdown]
# <a id="toc"></a>
# - 🐍 [0.0. IMPORTS](#001)
#     - [0.1 Variávesis Auxiliares](#0.1)
#     - [0.2 Funções Auxiliares](#0.2)
#     - [0.3 Configurações Auxiliares](#0.3)
#     - [0.4 Carregar Dados](#0.4)
#     <p>
#
# - 💻 [1.0 DESCRIÇÃO DOS DADOS](#002)
#     - [1.1 Dicionário de Dados](#1.1)
#     - [1.2 Renomear as Colunas](#1.2)
#     - [1.3 Dimensão dos Dados](#1.3)
#     - [1.4 Tipo dos Dados](#1.4)
#     - [1.5 Verificar NaN](#1.5)
#     - [1.6 Tratar NaN](#1.6)
#     - [1.7 Mudar Tipo de Dados](#1.7)
#     - [1.8 Estatística Descritiva](#1.8)
#     - [1.8.1 Dados Numéricos](#1.8.1)
#     <p>
#
# - 💼 [2.0 PERGUNTAS DE NEGÓCIO](#003)
#     -  🎯  [Perguntas Gerais](#2.0.1)
#         - [1. Quantos restaurantes únicos estão registrados?](#500)
#         - [2. Quantos países únicos estão registrados?](#501)
#         - [3. Quantas cidades únicas estão registradas?](#502)
#         - [4. Qual o total de avaliações feitas?](#503)
#         - [5. Qual o total de tipos de culinária registrados?](#504)
#         <p>
#     -  🇧🇷  [Perguntas Sobre os Países](#2.0.2)
#         - [1. Qual o nome do país que possui mais cidades registradas?](#505)
#         - [2. Qual o nome do país que possui mais restaurantes registrados?](#506)
#         - [3. Qual o nome do país que possui mais restaurantes com o nível de preço igual a 4 registrados?](#507)
#         - [4. Qual o nome do país que possui a maior quantidade de tipos de culinária distintos?](#508)
#         - [5. Qual o nome do país que possui a maior quantidade de avaliações feitas?](#509)
#         - [6. Qual o nome do país que possui a maior quantidade de restaurantes que fazem entrega?](#510)
#         - [7. Qual o nome do país que possui a maior quantidade de restaurantes que aceitam reservas?](#511)
#         - [8. Qual o nome do país que possui, na média, a maior quantidade de avaliações registrada?](#512)
#         - [9. Qual o nome do país que possui, na média, a maior nota média registrada?](#513)
#         - [10. Qual o nome do país que possui, na média, a menor nota média registrada?](#514)
#         - [11. Qual a média de preço de um prato para dois por país?](#515)
#         <p>
#
#     -  🌃  [Perguntas Sobre as Cidades](#2.0.3)
#         - [1. Qual o nome da cidade que possui mais restaurantes registrados?](#516)
#         - [2. Qual o nome da cidade que possui mais restaurantes com nota média acima de 4?](#517)
#         - [3. Qual o nome da cidade que possui mais restaurantes com nota média abaixo de 2.5?](#518)
#         - [4. Qual o nome da cidade que possui o maior valor médio de um prato para dois?](#519)
#         - [5. Qual o nome da cidade que possui a maior quantidade de tipos de culinária distintas?](#520)
#         - [6. Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem reservas?](#521)
#         - [7. Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem entregas?](#522)
#         - [8. Qual o nome da cidade que possui a maior quantidade de restaurantes que aceitam pedidos online?](#523)
#         <p>
#
#     - 🍔  [Perguntas Sobre os Restaurantes](#2.0.4)
#         - [1. Qual o nome do restaurante que possui a maior quantidade de avaliações?](#524)
#         - [2. Qual o nome do restaurante com a maior nota média?](#525)
#         - [3. Qual o nome do restaurante que possui o maior valor de uma prato para duas pessoas?](#526)
#         - [4. Qual o nome do restaurante de tipo de culinária brasileira que possui a menor média de avaliação?](#527)
#         - [5. Qual o nome do restaurante de tipo de culinária brasileira, e que é do Brasil, que possui a maior média de avaliação?](#528)
#         - [6. Os restaurantes que aceitam pedido online são também, na média, os restaurantes que mais possuem avaliações registradas?](#529)
#         - [7. Os restaurantes que fazem reservas são também, na média, os restaurantes que possuem o maior valor médio de um prato para duas pessoas?](#530)
#         - [8. Os restaurantes do tipo de culinária japonesa dos Estados Unidos da América possuem um valor médio de prato para duas pessoas maior que as churrascarias americanas (BBQ)?](#531)
#         <p>
#
#     - 🍣  [Perguntas Sobre os Tipos de Culinária](#2.0.5)
#          - [1. Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do restaurante com a maior média de avaliação?](#532)
#          - [2. Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do restaurante com a menor média de avaliação?](#533)
#          - [3. Dos restaurantes que possuem o tipo de culinária americana, qual o nome do restaurante com a maior média de avaliação?](#534)
#          - [4. Dos restaurantes que possuem o tipo de culinária americana, qual o nome do restaurante com a menor média de avaliação?](#535)
#          - [5. Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do restaurante com a maior média de avaliação?](#536)
#          - [6. Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do restaurante com a menor média de avaliação?](#537)
#          - [7. Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do restaurante com a maior média de avaliação?](#538)
#          - [8. Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do restaurante com a menor média de avaliação?](#539)
#          - [9. Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do restaurante com a maior média de avaliação?](#540)
#          - [10. Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do restaurante com a menor média de avaliação?](#541)
#          - [11. Qual o tipo de culinária que possui o maior valor médio de um prato para duas pessoas?](#542)
#          - [12. Qual o tipo de culinária que possui a maior nota média?](#543)
#          - [13. Qual o tipo de culinária que possui mais restaurantes que aceitam pedidos online e fazem entregas?](#544)
#     <p>
#
# -  🌍 [3.0 MAPAS](#004)
#     <p>
#
# -  📊 [4.0 GRÁFICOS](#005)
#     - [1. Quantidade de Restaurantes por País](#545)
#     - [2. Quantidade de Cidades Registradas por País](#546)
#     - [3. Média de Avaliações](#547)
#     - [4. Média de Preço de um prato para duas pessoas](#548)
#     - [5. Média da Nota dos Restaurantes por País](#549)

# %% [markdown]
# <a id="001"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">0.0  <span style='color:#D2BA9E'>|</span> Imports</div>

# %%
import pandas as pd
import numpy as np
import inflection
import plotly.express as px
from PIL import Image
#import streamlit as st
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
#from streamlit_folium import folium_static
from IPython import display

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="0.1"></a>
# ## <b style="color:#D2BA9E; font-size:80%">0.1 <span style='color:#1F2E55'> Variáveis Auxiliares</span></b>

# %%
COUNTRIES = {
    1: "India",
    14: "Australia",
    30: "Brazil",
    37: "Canada",
    94: "Indonesia",
    148: "New Zeland",
    162: "Philippines",
    166: "Qatar",
    184: "Singapure",
    189: "South Africa",
    191: "Sri Lanka",
    208: "Turkey",
    214: "United Arab Emirates",
    215: "England",
    216: "United States of America",
}


COLORS = {
    "3F7E00": "darkgreen",
    "5BA829": "green",
    "9ACD32": "lightgreen",
    "CDD614": "orange",
    "FFBA00": "red",
    "CBCBC8": "darkred",
    "FF7800": "darkred",
}

# %%
FILE_PATH = '/home/vinicius/repos/projeto_ftc_vorges/datasets/zomato.csv'

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="0.2"></a>
# ## <b style="color:#D2BA9E; font-size:80%">0.2 <span style='color:#1F2E55'> Funções Auxiliares</span></b>

# %%
def dataframe_dimensions(dataframe):
    print(f'Número de linhas: {dataframe.shape[0]}')
    print(f'Número de colunas: {dataframe.shape[1]}')
    
    return None

# %%
def get_numerical_attributes(dataframe):
    return dataframe.select_dtypes(include=['int64', 'float64'])

# %%
def get_cat_attributes(dataframe):
    return dataframe.select_dtypes(exclude=['int64','float64'])

# %%
def describe_attributes(dataframe):
    return dataframe.describe()

# %%
# Mostrar os numeros com 2 casas decimais
pd.set_option('display.precision', 2)

# Tratar valores em notação cientifica
pd.set_option('float_format', '{:.3f}'.format)

# Voltar ao normal dos dados com casas decimais
#pd.reset_option('^display.', silent=True)

# %%
def get_first_order_statistics(dataframe):
    # Métricas de Tendência Central
    mean = pd.DataFrame(dataframe.apply(np.mean)).T
    median = pd.DataFrame(dataframe.apply(np.median)).T

    # Métricas de dispersão
    min_ = pd.DataFrame(dataframe.apply(min)).T
    max_ = pd.DataFrame(dataframe.apply(max)).T
    range_ = pd.DataFrame(dataframe.apply(lambda x: x.max() - x.min())).T
    std = pd.DataFrame(dataframe.apply(np.std)).T
    skew = pd.DataFrame(dataframe.apply(lambda x: x.skew())).T
    kurtosis = pd.DataFrame(dataframe.apply(lambda x: x.kurtosis())).T

    # Métricas de Concatenação
    m = pd.concat([min_, max_, range_, mean, median, std, skew, kurtosis]).T.reset_index()
    m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
    
    return m

# %%
# renomear as colunas em snakecase
def rename_columns(dataframe):
    df = dataframe.copy()

    title = lambda x: inflection.titleize(x)

    snakecase = lambda x: inflection.underscore(x)

    spaces = lambda x: x.replace(" ", "")

    cols_old = list(df.columns)

    cols_old = list(map(title, cols_old))

    cols_old = list(map(spaces, cols_old))

    cols_new = list(map(snakecase, cols_old))

    df.columns = cols_new

    return df

# %%
# Substituir o código do país pelo seu nome
def country_name(country_id):
    return COUNTRIES[country_id]

# %%
# Substituir o código da cor por seu nome
def color_name(color_code):
    return COLORS[color_code]

# %%
# Substituir o price_range pelas nomes
def create_price_tye(price_range):
    if price_range == 1:
        return "cheap"
    elif price_range == 2:
        return "normal"
    elif price_range == 3:
        return "expensive"
    else:
        return "gourmet"

# %%
def adjust_columns_order(dataframe):
    df = dataframe.copy()

    new_cols_order = [
        "restaurant_id",
        "restaurant_name",
        "country",
        "city",
        "address",
        "locality",
        "locality_verbose",
        "longitude",
        "latitude",
        "cuisines",
        "price_type",
        "average_cost_for_two",
        "currency",
        "has_table_booking",
        "has_online_delivery",
        "is_delivering_now",
        "aggregate_rating",
        "rating_color",
        "color_name",
        "rating_text",
        "votes",
    ]

    return df.loc[:, new_cols_order]

# %%
def process_data(file_path):
    
    df = pd.read_csv(file_path)

    df = df.dropna()

    df = rename_columns(df)

    df["price_type"] = df.loc[:, "price_range"].apply(lambda x: create_price_tye(x))

    df["country"] = df.loc[:, "country_code"].apply(lambda x: country_name(x))

    df["color_name"] = df.loc[:, "rating_color"].apply(lambda x: color_name(x))

    df["cuisines"] = df.loc[:, "cuisines"].apply(lambda x: x.split(",")[0])

    df = df.drop_duplicates()

    df = adjust_columns_order(df)

    df.to_csv('/home/vinicius/repos/projeto_ftc_vorges/datasets/data_processed.csv', index=False)

    return df

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="0.3"></a>
# ## <b style="color:#D2BA9E; font-size:80%">0.3 <span style='color:#1F2E55'> Configurações Auxiliares</span></b>

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="0.4"></a>
# ## <b style="color:#D2BA9E; font-size:80%">0.4 <span style='color:#1F2E55'> Carregar Dados</span></b>

# %%
df_raw = pd.read_csv(FILE_PATH)
df_raw.head(3)
# Out:
#    Restaurant ID             Restaurant Name  Country Code            City  \
# 0        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 1        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
# 2        6314542                   Blackbird           162     Makati City
#
#                                              Address  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 1  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# 2  Nielson Tower, Ayala Triangle Gardens, Salcedo...
#
#                                             Locality  \
# 0                                   BF International
# 1                                   BF International
# 2  Ayala Triangle Gardens, Salcedo Village, Makat...
#
#                                     Locality Verbose  Longitude  Latitude  \
# 0                   BF International, Las Piñas City    121.010    14.448
# 1                   BF International, Las Piñas City    121.010    14.448
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="002"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">1.0  <span style='color:#D2BA9E'>|</span> Descrição dos Dados</div>

# %%
df1 = df_raw.copy()
df1.head(10)
# Out:
#    Restaurant ID               Restaurant Name  Country Code            City  \
# 0        6310675    Mama Lou's Italian Kitchen           162  Las Piñas City
# 1        6310675    Mama Lou's Italian Kitchen           162  Las Piñas City
# 2        6314542                     Blackbird           162     Makati City
# 3        6301293                      Banapple           162     Makati City
# 4        6315689                      Bad Bird           162     Makati City
# 5        6304833                         Manam           162     Makati City
# 6       18409457            Soban K-Town Grill           162     Makati City
# 7       18607559    Bluesmith Coffee & Kitchen           162     Makati City
# 8        6314001  Motorino Pizzeria Napoletana           162     Makati City
# 9       18189398                       Shi Lin           162     Makati City
#
#                                              Address  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...
# ...

# %% [markdown]
# <a id="1.1"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1.1 <span style='color:#1F2E55'> Dicionário de Dados</span></b>

# %% [markdown]
# **Restaurant ID** - Número de Identificação \
# **Restaurant Name** - Nome do Restaurante\
# **Country Code** - Código do País\
# **City** - Nome da Cidade do Restaurante\
# **Address** - Endereço\
# **Locality** - Endereço Curto do Restaurante\
# **Locality Verbose** - Endereço Completo do Restaurante\
# **Longitude** - Longitude\
# **Latitude** - Latitude\
# **Cuisines** - Tipo de culinária servida\
# **Average Cost for two** - Custo Médio se duas pessoas visitarem o Restaurante\
# **Currency** - Dólar\
# **Has Table booking** - Podemos reservar mesas no restaurante? Sim/não\
# **Has Online delivery** - Podemos ter entrega online? Sim/não\
# **Is delivering now** - O restaurante está entregando comida agora? Sim/não\
# **Switch to order menu** - Alternar para o menu de pedidos? Sim/não\
# **Price range** - Preço categorizado entre 1 -4\
# **Aggregate rating** -  Categorizando classificações entre 1-5\
# **Rating color** - Cores diferentes representando a classificação do cliente\
# **Rating text** - Classificação diferente como excelente, muito bom, bom, médio, ruim, não avaliado\
# **Votes** - Número de votos recebidos pelo Restaurante dos clientes

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="1.2"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1.2 <span style='color:#1F2E55'> Renomear Colunas</span></b>

# %%
# Chamar a função para renomear as colunas
df1 = rename_columns(df1)
df1.head(1)
# Out:
#    restaurant_id             restaurant_name  country_code            city  \
# 0        6310675  Mama Lou's Italian Kitchen           162  Las Piñas City
#
#                                              address          locality  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...  BF International
#
#                    locality_verbose  longitude  latitude cuisines  \
# 0  BF International, Las Piñas City    121.010    14.448  Italian
#
#    average_cost_for_two          currency  has_table_booking  \
# 0                  1100  Botswana Pula(P)                  1
#
#    has_online_delivery  is_delivering_now  switch_to_order_menu  price_range  \
# 0                    0                  0                     0            3
#
#    aggregate_rating rating_color rating_text  votes
# 0             4.600       3F7E00   Excellent    619

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="1.3"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1.3 <span style='color:#1F2E55'> Dimensão dos Dados</span></b>

# %%
# Chamar a função
dataframe_dimensions(df1)
# Out:
# Número de linhas: 7527
# Número de colunas: 21

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="1.4"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1.4 <span style='color:#1F2E55'> Tipo de Dados</span></b>

# %%
df1.dtypes
# Out:
# restaurant_id             int64
# restaurant_name          object
# country_code              int64
# city                     object
# address                  object
# locality                 object
# locality_verbose         object
# longitude               float64
# latitude                float64
# cuisines                 object
# average_cost_for_two      int64
# currency                 object
# has_table_booking         int64
# has_online_delivery       int64
# is_delivering_now         int64
# switch_to_order_menu      int64
# price_range               int64
# aggregate_rating        float64
# rating_color             object
# rating_text              object
# votes                     int64
# dtype: object

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="1.5"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1.5 <span style='color:#1F2E55'> Verificar NaN</span></b>

# %%
df1.isna().sum()
# Out:
# restaurant_id            0
# restaurant_name          0
# country_code             0
# city                     0
# address                  0
# locality                 0
# locality_verbose         0
# longitude                0
# latitude                 0
# cuisines                15
# average_cost_for_two     0
# currency                 0
# has_table_booking        0
# has_online_delivery      0
# is_delivering_now        0
# switch_to_order_menu     0
# price_range              0
# aggregate_rating         0
# rating_color             0
# rating_text              0
# votes                    0
# dtype: int64

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="1.6"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1.6 <span style='color:#1F2E55'> Tratar NaN</span></b>

# %%
df1 = df1.dropna()
df1.isna().sum()
# Out:
# restaurant_id           0
# restaurant_name         0
# country_code            0
# city                    0
# address                 0
# locality                0
# locality_verbose        0
# longitude               0
# latitude                0
# cuisines                0
# average_cost_for_two    0
# currency                0
# has_table_booking       0
# has_online_delivery     0
# is_delivering_now       0
# switch_to_order_menu    0
# price_range             0
# aggregate_rating        0
# rating_color            0
# rating_text             0
# votes                   0
# dtype: int64

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="1.7"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1.7 <span style='color:#1F2E55'> Mudar Tipo de Dados</span></b>

# %% [markdown]
# Neste caso não há a necessidade de mudança no tipo de dados.

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="1.8"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1.8 <span style='color:#1F2E55'> Estatística Descritiva</span></b>

# %%
# Chamar a função que retorna as variáveis numéricas
numerical_data = get_numerical_attributes(df1)

# %%
# Chamar a função que retorna as variáveis categóricas
cat_data = get_cat_attributes(df1)

# %%
cat_data.apply( lambda x: x.unique().shape[0])
# Out:
# restaurant_name     5901
# city                 125
# address             6753
# locality            2272
# locality_verbose    2356
# cuisines            2832
# currency              12
# rating_color           7
# rating_text           28
# dtype: int64

# %%
describe_attributes( df1 )
# Out:
#        restaurant_id  country_code  longitude  latitude  average_cost_for_two  \
# count       7512.000      7512.000   7512.000  7512.000              7512.000
# mean    10543268.354        93.135     33.763    19.312              7165.669
# std      7075487.795        99.027     77.375    23.274            290896.706
# min          549.000         1.000   -122.700   -41.330                 0.000
# 25%      3500048.000         1.000     -4.258    12.916                60.000
# 50%      7701329.000        30.000     73.783    25.237               290.000
# 75%     17147091.250       214.000     79.833    31.637               600.000
# max     19040277.000       216.000    175.311    55.977          25000017.000
#
#        has_table_booking  has_online_delivery  is_delivering_now  \
# count           7512.000             7512.000           7512.000
# mean               0.062                0.353              0.175
# std                0.242                0.478              0.380
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="1.9"></a>
# ## <b style="color:#D2BA9E; font-size:80%"> <span style='color:#1F2E55'> Tipo de Distribuição das variáveis - Histograma variáveis numéricas</span></b>

# %%
numerical_data.hist(bins=15, figsize=(15,10), color='darkmagenta');

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="1.8.1"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1.8.1 <span style='color:#1F2E55'> Dados Numéricos</span></b>

# %%
get_first_order_statistics(numerical_data)
# Out:
#               attributes      min          max        range         mean  \
# 0          restaurant_id  549.000 19040277.000 19039728.000 10543268.354
# 1           country_code    1.000      216.000      215.000       93.135
# 2              longitude -122.700      175.311      298.011       33.763
# 3               latitude  -41.330       55.977       97.307       19.312
# 4   average_cost_for_two    0.000 25000017.000 25000017.000     7165.669
# 5      has_table_booking    0.000        1.000        1.000        0.062
# 6    has_online_delivery    0.000        1.000        1.000        0.353
# 7      is_delivering_now    0.000        1.000        1.000        0.175
# 8   switch_to_order_menu    0.000        0.000        0.000        0.000
# 9            price_range    1.000        4.000        3.000        2.625
# 10      aggregate_rating    0.000        4.900        4.900        4.123
# 11                 votes    0.000    41333.000    41333.000      617.483
#
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="003"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">2.0  <span style='color:#D2BA9E'>|</span> Perguntas de Negócio</div>

# %%
# Chamar a função para processar os dados
df2 = process_data(FILE_PATH)
df2.head(1)
# Out:
#    restaurant_id             restaurant_name      country            city  \
# 0        6310675  Mama Lou's Italian Kitchen  Philippines  Las Piñas City
#
#                                              address          locality  \
# 0  Block 1, Lot 36, Tropical Avenue Corner Tropic...  BF International
#
#                    locality_verbose  longitude  latitude cuisines price_type  \
# 0  BF International, Las Piñas City    121.010    14.448  Italian  expensive
#
#    average_cost_for_two          currency  has_table_booking  \
# 0                  1100  Botswana Pula(P)                  1
#
#    has_online_delivery  is_delivering_now  aggregate_rating rating_color  \
# 0                    0                  0             4.600       3F7E00
#
#   color_name rating_text  votes
# 0  darkgreen   Excellent    619

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="2.0.1"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">  <span style='color:#D2BA9E'>|</span> Geral</div>

# %% [markdown]
# <a id="500"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1. <span style='color:#1F2E55'> Quantos restaurantes únicos estão registrados?</span></b>

# %%
len(df2['restaurant_id'])
# Out:
# 6929

# %%
df2['restaurant_id'].shape[0]
# Out:
# 6929

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="501"></a>
# ## <b style="color:#D2BA9E; font-size:80%">2. <span style='color:#1F2E55'> Quantos países únicos estão registrados?</span></b>

# %%
len(df2['country'].unique())
# Out:
# 15

# %%
df2.loc[:, 'country'].nunique()
# Out:
# 15

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="502"></a>
# ## <b style="color:#D2BA9E; font-size:80%">3. <span style='color:#1F2E55'> Quantas cidades únicas estão registradas?</span></b>

# %%
len(df2['city'].unique())
# Out:
# 125

# %%
df2.loc[:, 'city'].nunique()
# Out:
# 125

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="503"></a>
# ## <b style="color:#D2BA9E; font-size:80%">4. <span style='color:#1F2E55'> Qual o total de avaliações feitas?</span></b>

# %%
df2['votes'].sum()
# Out:
# 4194533

# %%
df2.loc[:, 'votes'].sum()
# Out:
# 4194533

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="504"></a>
# ## <b style="color:#D2BA9E; font-size:80%">5. <span style='color:#1F2E55'> Qual o total de tipos de culinária registrados?</span></b>

# %%
len(df2['cuisines'].unique())
# Out:
# 165

# %%
df2.loc[:, 'cuisines'].nunique()
# Out:
# 165

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="2.0.2"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">  <span style='color:#D2BA9E'>|</span> País</div>

# %% [markdown]
# <a id="505"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1. <span style='color:#1F2E55'>  Qual o nome do país que possui mais cidades registradas?</span></b>

# %%
( df2.loc[:,['country','city']].groupby('country')
                             .nunique()
                             .sort_values('city',ascending=False)
                             .reset_index() )
# Out:
#                      country  city
# 0                      India    49
# 1   United States of America    22
# 2                Philippines    12
# 3               South Africa    12
# 4                    England     5
# 5                 New Zeland     4
# 6       United Arab Emirates     4
# 7                  Australia     3
# 8                     Brazil     3
# 9                     Canada     3
# 10                 Indonesia     3
# 11                    Turkey     2
# 12                     Qatar     1
# 13                 Singapure     1
# 14                 Sri Lanka     1

# %%
( df2.loc[:,['country','city']].groupby('country')
                             .nunique()
                             .sort_values('city',ascending=False)
                             .reset_index()
                             .iloc[0,0])
# Out:
# 'India'

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="506"></a>
# ## <b style="color:#D2BA9E; font-size:80%">2. <span style='color:#1F2E55'>  Qual o nome do país que possui mais restaurantes registrados?</span></b>

# %%
( df2.loc[:, ['country','restaurant_id']].groupby('country')
                                     .nunique()
                                     .sort_values('restaurant_id', ascending=False)
                                     .reset_index() )
# Out:
#                      country  restaurant_id
# 0                      India           3111
# 1   United States of America           1374
# 2                    England            400
# 3               South Africa            346
# 4       United Arab Emirates            300
# 5                     Brazil            240
# 6                 New Zeland            239
# 7                  Australia            180
# 8                     Canada            180
# 9                     Turkey            159
# 10                 Indonesia             80
# 11               Philippines             80
# 12                     Qatar             80
# 13                 Singapure             80
# 14                 Sri Lanka             80

# %%
( df2.loc[:, ['country','restaurant_id']].groupby('country')
                                     .count()
                                     .sort_values('restaurant_id', ascending=False)
                                     .reset_index()
                                     .iloc[0,0] )
# Out:
# 'India'

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="507"></a>
# ## <b style="color:#D2BA9E; font-size:80%">3. <span style='color:#1F2E55'>  Qual o nome do país que possui mais restaurantes com o nível de preço igual a 4 registrados?</span></b>

# %%
( df2.loc[ df2['aggregate_rating'] >= 4 , ['restaurant_id','country'] ]
                                        .groupby('country')
                                        .count()
                                        .sort_values('restaurant_id', ascending=False)
                                        .reset_index()
                                        .iloc[0,0] )
# Out:
# 'India'

# %%
( df2.loc[ df2['aggregate_rating'] >= 4 , ['restaurant_id','country'] ]
                                        .groupby('country')
                                        .count()
                                        .sort_values('restaurant_id', ascending=False)
                                        .reset_index() )
# Out:
#                      country  restaurant_id
# 0                      India           2202
# 1   United States of America           1313
# 2                    England            256
# 3               South Africa            256
# 4       United Arab Emirates            185
# 5                 New Zeland            184
# 6                  Australia            167
# 7                     Canada            163
# 8                     Turkey            144
# 9                     Brazil            116
# 10                 Indonesia             79
# 11               Philippines             79
# 12                 Singapure             71
# 13                     Qatar             70
# 14                 Sri Lanka             53

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="508"></a>
# ## <b style="color:#D2BA9E; font-size:80%">4. <span style='color:#1F2E55'>  Qual o nome do país que possui a maior quantidade de tipos de culinária distintos?</span></b>

# %%
( df2.loc[:, ['cuisines','country']].groupby('country')
                                  .nunique()
                                  .sort_values('cuisines', ascending=False)
                                  .reset_index()
                                  .iloc[0,0] )
# Out:
# 'India'

# %%
( df2.loc[:, ['cuisines','country']].groupby('country')
                                  .nunique()
                                  .sort_values('cuisines', ascending=False)
                                  .reset_index() )
# Out:
#                      country  cuisines
# 0                      India        77
# 1   United States of America        74
# 2                    England        52
# 3       United Arab Emirates        46
# 4                  Australia        43
# 5                     Brazil        43
# 6                     Canada        42
# 7               South Africa        42
# 8                 New Zeland        37
# 9                      Qatar        31
# 10                    Turkey        28
# 11                 Sri Lanka        26
# 12                 Indonesia        21
# 13                 Singapure        21
# 14               Philippines        14

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="509"></a>
# ## <b style="color:#D2BA9E; font-size:80%">5. <span style='color:#1F2E55'>  Qual o nome do país que possui a maior quantidade de avaliações feitas?</span></b>

# %%
( df2.loc[:, ['votes','country']].groupby('country')
                               .count()
                               .sort_values('votes', ascending=False)
                               .reset_index().iloc[0,0] )
# Out:
# 'India'

# %%
( df2.loc[:, ['votes','country']].groupby('country')
                               .count()
                               .sort_values('votes', ascending=False)
                               .reset_index() )
# Out:
#                      country  votes
# 0                      India   3111
# 1   United States of America   1374
# 2                    England    400
# 3               South Africa    346
# 4       United Arab Emirates    300
# 5                     Brazil    240
# 6                 New Zeland    239
# 7                  Australia    180
# 8                     Canada    180
# 9                     Turkey    159
# 10                 Indonesia     80
# 11               Philippines     80
# 12                     Qatar     80
# 13                 Singapure     80
# 14                 Sri Lanka     80

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="510"></a>
# ## <b style="color:#D2BA9E; font-size:80%">6. <span style='color:#1F2E55'>  Qual o nome do país que possui a maior quantidade de restaurantes que fazem entrega?</span></b>

# %%
( df2.loc[ df2['is_delivering_now'] == 1, ['restaurant_id','country'] ].groupby('country')
                                                                     .count()
                                                                     .sort_values('restaurant_id', ascending=False)
                                                                     .reset_index()
                                                                     .iloc[0,0] )
# Out:
# 'India'

# %%
( df2.loc[ df2['is_delivering_now'] == 1, ['restaurant_id','country'] ].groupby('country')
                                                                     .count()
                                                                     .sort_values('restaurant_id', ascending=False)
                                                                     .reset_index() )
# Out:
#                 country  restaurant_id
# 0                 India           1150
# 1  United Arab Emirates             52
# 2           Philippines              7
# 3                 Qatar              3

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="511"></a>
# ## <b style="color:#D2BA9E; font-size:80%">7. <span style='color:#1F2E55'>  Qual o nome do país que possui a maior quantidade de restaurantes que aceitam reservas?</span></b>

# %%
( df2.loc[ df2['has_online_delivery'] == 1, ['restaurant_id','country'] ]
                                          .groupby('country')
                                          .count()
                                          .sort_values('restaurant_id', ascending=False)
                                          .reset_index()
                                          .iloc[0,0] )
# Out:
# 'India'

# %%
( df2.loc[ df2['has_online_delivery'] == 1, ['restaurant_id','country'] ]
                                          .groupby('country')
                                          .count()
                                          .sort_values('restaurant_id', ascending=False)
                                          .reset_index() )
# Out:
#                 country  restaurant_id
# 0                 India           2177
# 1  United Arab Emirates            205
# 2                 Qatar             37
# 3           Philippines              9

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="512"></a>
# ## <b style="color:#D2BA9E; font-size:80%">8. <span style='color:#1F2E55'>  Qual o nome do país que possui, na média, a maior quantidade de avaliações registradas?</span></b>

# %%
( df2.loc[:, ['votes','country']].groupby('country')
                               .mean()
                               .sort_values('votes', ascending=False)
                               .reset_index()
                               .iloc[0,0] )
# Out:
# 'Indonesia'

# %%
( df2.loc[:, ['votes','country']].groupby('country')
                               .mean()
                               .sort_values('votes', ascending=False)
                               .reset_index())
# Out:
#                      country    votes
# 0                  Indonesia 1112.825
# 1                      India  900.085
# 2                  Australia  724.206
# 3                     Turkey  630.145
# 4                Philippines  604.975
# 5       United Arab Emirates  591.880
# 6                     Canada  583.433
# 7   United States of America  380.166
# 8                      Qatar  376.325
# 9               South Africa  236.818
# 10                New Zeland  219.799
# 11                 Sri Lanka  151.662
# 12                   England   99.890
# 13                 Singapure   22.775
# 14                    Brazil   12.404

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="513"></a>
# ## <b style="color:#D2BA9E; font-size:80%">9. <span style='color:#1F2E55'>  Qual o nome do país que possui, na média, a maior nota média registrada?</span></b>

# %%
( df2.loc[:, ['aggregate_rating','country']].groupby('country')
                                          .mean()
                                          .sort_values('aggregate_rating', ascending=False)
                                          .reset_index()
                                          .iloc[0,0] )
# Out:
# 'Indonesia'

# %%
( df2.loc[:, ['aggregate_rating','country']].groupby('country')
                                          .mean()
                                          .sort_values('aggregate_rating', ascending=False)
                                          .reset_index() )
# Out:
#                      country  aggregate_rating
# 0                  Indonesia             4.601
# 1                Philippines             4.464
# 2                  Singapure             4.435
# 3   United States of America             4.403
# 4                  Australia             4.373
# 5                     Canada             4.322
# 6                     Turkey             4.310
# 7                      Qatar             4.240
# 8                 New Zeland             4.164
# 9               South Africa             4.062
# 10                 Sri Lanka             4.058
# 11                   England             4.042
# 12                     India             4.037
# 13      United Arab Emirates             4.024
# 14                    Brazil             3.322

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="514"></a>
# ## <b style="color:#D2BA9E; font-size:80%">10. <span style='color:#1F2E55'>  Qual o nome do país que possui, na média, a menor nota média registrada?</span></b>

# %%
( df2.loc[:, ['aggregate_rating','country']].groupby('country')
                                          .mean()
                                          .sort_values('aggregate_rating', ascending=True)
                                          .reset_index()
                                          .iloc[0,0] )
# Out:
# 'Brazil'

# %%
( df2.loc[:, ['aggregate_rating','country']].groupby('country')
                                          .mean()
                                          .sort_values('aggregate_rating', ascending=True)
                                          .reset_index() )
# Out:
#                      country  aggregate_rating
# 0                     Brazil             3.322
# 1       United Arab Emirates             4.024
# 2                      India             4.037
# 3                    England             4.042
# 4                  Sri Lanka             4.058
# 5               South Africa             4.062
# 6                 New Zeland             4.164
# 7                      Qatar             4.240
# 8                     Turkey             4.310
# 9                     Canada             4.322
# 10                 Australia             4.373
# 11  United States of America             4.403
# 12                 Singapure             4.435
# 13               Philippines             4.464
# 14                 Indonesia             4.601

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="515"></a>
# ## <b style="color:#D2BA9E; font-size:80%">11. <span style='color:#1F2E55'>  Qual a média de preço de um prato para dois por país?</span></b>

# %%
( df2.loc[:, ['average_cost_for_two','country']].groupby('country')
                                              .mean()
                                              .sort_values('average_cost_for_two', ascending=False)
                                              .reset_index() )
# Out:
#                      country  average_cost_for_two
# 0                  Indonesia            303000.000
# 1                  Australia            138959.783
# 2                  Sri Lanka              2579.375
# 3                Philippines              1227.825
# 4                      India               704.401
# 5               South Africa               339.228
# 6                      Qatar               174.000
# 7       United Arab Emirates               153.717
# 8                  Singapure               141.438
# 9                     Brazil               138.812
# 10                    Turkey               128.585
# 11                New Zeland                62.155
# 12  United States of America                55.030
# 13                   England                43.510
# 14                    Canada                41.861

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="2.0.3"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">  <span style='color:#D2BA9E'>|</span> Cidades</div>

# %% [markdown]
# <a id="516"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1. <span style='color:#1F2E55'>  Qual o nome da cidade que possui mais restaurantes registrados?</span></b>

# %%
( df2.loc[:, ['restaurant_id','city']].groupby('city')
                                    .count()
                                    .sort_values('restaurant_id', ascending=False)
                                    .reset_index()
                                    .iloc[0,0] )
# Out:
# 'Abu Dhabi'

# %%
( df2.loc[:, ['restaurant_id','city']].groupby('city')
                                    .count()
                                    .sort_values('restaurant_id', ascending=False)
                                    .reset_index() )
# Out:
#                    city  restaurant_id
# 0             Abu Dhabi             80
# 1                Mysore             80
# 2               Glasgow             80
# 3                   Goa             80
# 4              Guwahati             80
# 5              Hamilton             80
# 6               Houston             80
# 7                Indore             80
# 8                Jaipur             80
# 9                Kanpur             80
# 10                Kochi             80
# 11              Kolkata             80
# 12               London             80
# 13              Lucknow             80
# 14           Manchester             80
# 15            Mangalore             80
# 16               Nagpur             80
# 17               Durban             80
# 18                 Ooty             80
# 19                Patna             80
# 20             Pretoria             80
# 21           Puducherry             80
# 22                 Pune             80
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="517"></a>
# ## <b style="color:#D2BA9E; font-size:80%">2. <span style='color:#1F2E55'>  Qual o nome da cidade que possui mais restaurantes com nota média acima de 4?</span></b>

# %%
( df2.loc[ df2['aggregate_rating'] >= 4 , ['restaurant_id','city']].groupby('city')
                                                                 .count()
                                                                 .sort_values('restaurant_id', ascending= False)
                                                                 .reset_index()
                                                                 .iloc[0,0] )
# Out:
# 'London'

# %%
( df2.loc[ df2['aggregate_rating'] >= 4 , ['restaurant_id','city']].groupby('city')
                                                                 .count()
                                                                 .sort_values('restaurant_id', ascending= False)
                                                                 .reset_index() )
# Out:
#                    city  restaurant_id
# 0                London             80
# 1             Bangalore             79
# 2               Houston             77
# 3                  Pune             77
# 4              İstanbul             76
# 5               Kolkata             76
# 6               Jakarta             75
# 7              Auckland             75
# 8                Austin             73
# 9               Chennai             72
# 10               Mumbai             71
# 11            Singapore             71
# 12                  Goa             70
# 13      Wellington City             70
# 14                Dubai             70
# 15                 Doha             70
# 16               Dallas             68
# 17              Lucknow             68
# 18               Ankara             68
# 19            Ahmedabad             67
# 20             Ludhiana             65
# 21             Pretoria             64
# 22                Surat             64
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="518"></a>
# ## <b style="color:#D2BA9E; font-size:80%">3. <span style='color:#1F2E55'>  Qual o nome da cidade que possui mais restaurantes com nota média abaixo de 2.5?</span></b>

# %%
( df2.loc[ df2['aggregate_rating'] < 2.5, ['restaurant_id','city']]
                                        .groupby('city')
                                        .count()
                                        .sort_values('restaurant_id', ascending=False)
                                        .reset_index()
                                        .iloc[0,0] )
# Out:
# 'Gangtok'

# %%
( df2.loc[ df2['aggregate_rating'] < 2.5, ['restaurant_id','city']]
                                        .groupby('city')
                                        .count()
                                        .sort_values('restaurant_id', ascending=False)
                                        .reset_index() )
# Out:
#               city  restaurant_id
# 0          Gangtok             33
# 1             Ooty             19
# 2        São Paulo             16
# 3         Brasília             15
# 4   Rio de Janeiro             12
# 5       Manchester              7
# 6          Clarens              4
# 7           Shimla              4
# 8        Edinburgh              2
# 9         Hamilton              2
# 10      Puducherry              2
# 11          Durban              1
# 12          Nashik              1
# 13         Colombo              1
# 14           Perth              1
# 15        Pretoria              1
# 16          Ankara              1

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="519"></a>
# ## <b style="color:#D2BA9E; font-size:80%">4. <span style='color:#1F2E55'>  Qual o nome da cidade que possui o maior valor médio de um prato para dois?</span></b>

# %%
( df2.loc[:, ['average_cost_for_two','city']].groupby('city')
                                           .mean()
                                           .sort_values('average_cost_for_two', ascending=False)
                                           .reset_index()
                                           .iloc[0,0] )
# Out:
# 'Adelaide'

# %%
( df2.loc[:, ['average_cost_for_two','city']].groupby('city')
                                           .mean()
                                           .sort_values('average_cost_for_two', ascending=False)
                                           .reset_index() )
# Out:
#                    city  average_cost_for_two
# 0              Adelaide            416734.133
# 1               Jakarta            309605.263
# 2             Tangerang            180000.000
# 3                 Bogor            175000.000
# 4            Pasay City              4000.000
# 5               Colombo              2579.375
# 6                 Noida              1407.143
# 7               Gurgaon              1375.000
# 8                 Thane              1375.000
# 9                Mumbai              1372.368
# 10        Tagaytay City              1333.333
# 11          Makati City              1308.824
# 12            Bangalore              1291.250
# 13          Taguig City              1247.222
# 14     Mandaluyong City              1227.600
# 15             Zirakpur              1200.000
# 16        Marikina City              1200.000
# 17            Ghaziabad              1200.000
# 18                 Pune              1195.000
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="520"></a>
# ## <b style="color:#D2BA9E; font-size:80%">5. <span style='color:#1F2E55'>  Qual o nome da cidade que possui a maior quantidade de tipos de culinária distintas?</span></b>

# %%
( df2.loc[:, ['cuisines','city']].groupby('city')
                               .nunique()
                               .sort_values('cuisines', ascending=False)
                               .reset_index()
                               .iloc[0,0] )
# Out:
# 'Birmingham'

# %%
( df2.loc[:, ['cuisines','city']].groupby('city')
                               .nunique()
                               .sort_values('cuisines', ascending=False)
                               .reset_index().head(10) )
# Out:
#            city  cuisines
# 0    Birmingham        32
# 1          Doha        31
# 2      Montreal        30
# 3     São Paulo        30
# 4    Manchester        30
# 5       Houston        30
# 6         Perth        29
# 7  Philadelphia        29
# 8      Portland        28
# 9       Calgary        28

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="521"></a>
# ## <b style="color:#D2BA9E; font-size:80%">6. <span style='color:#1F2E55'>  Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem reservas?</span></b>

# %%
( df2.loc[ df2['has_table_booking'] == 1, ['restaurant_id','city']].groupby('city')
                                                                 .count()
                                                                 .sort_values('restaurant_id', ascending=False)
                                                                 .reset_index()
                                                                 .iloc[0,0] )
# Out:
# 'Bangalore'

# %%
( df2.loc[ df2['has_table_booking'] == 1, ['restaurant_id','city']].groupby('city')
                                                                 .count()
                                                                 .sort_values('restaurant_id', ascending=False)
                                                                 .reset_index().head(10) )
# Out:
#         city  restaurant_id
# 0  Bangalore             42
# 1    Chennai             28
# 2       Pune             25
# 3     Mumbai             18
# 4   Brisbane             17
# 5   Auckland             17
# 6  New Delhi             16
# 7     London             15
# 8  Edinburgh             13
# 9    Jakarta             13

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="522"></a>
# ## <b style="color:#D2BA9E; font-size:80%">7. <span style='color:#1F2E55'>  Qual o nome da cidade que possui a maior quantidade de restaurantes que fazem entregas?</span></b>

# %%
( df2.loc[ df2['is_delivering_now'] == 1, ['restaurant_id','city']]
                                        .groupby('city')
                                        .count()
                                        .sort_values('restaurant_id', ascending=False)
                                        .reset_index()
                                        .iloc[0,0] )
# Out:
# 'Vadodara'

# %%
( df2.loc[ df2['is_delivering_now'] == 1, ['restaurant_id','city']]
                                        .groupby('city')
                                        .count()
                                        .sort_values('restaurant_id', ascending=False)
                                        .reset_index().head(10) )
# Out:
#          city  restaurant_id
# 0    Vadodara             48
# 1    Amritsar             48
# 2  Aurangabad             47
# 3    Ludhiana             46
# 4      Bhopal             46
# 5    Dehradun             45
# 6      Ranchi             42
# 7      Jaipur             42
# 8   Ahmedabad             41
# 9    Varanasi             40

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="523"></a>
# ## <b style="color:#D2BA9E; font-size:80%">8. <span style='color:#1F2E55'>  Qual o nome da cidade que possui a maior quantidade de restaurantes que aceitam pedidos online?</span></b>

# %%
( df2.loc[ df2['has_online_delivery'] == 1, ['restaurant_id','city'] ]
                                            .groupby('city')
                                            .count()
                                            .sort_values('restaurant_id', ascending=False)
                                            .reset_index()
                                            .iloc[0,0] )
# Out:
# 'Bhopal'

# %%
( df2.loc[ df2['has_online_delivery'] == 1, ['restaurant_id','city'] ]
                                            .groupby('city')
                                            .count()
                                            .sort_values('restaurant_id', ascending=False)
                                            .reset_index()
                                            .head(10))
# Out:
#          city  restaurant_id
# 0      Bhopal             75
# 1    Vadodara             74
# 2   Abu Dhabi             71
# 3     Sharjah             71
# 4      Nagpur             69
# 5  Aurangabad             69
# 6       Patna             69
# 7      Ranchi             69
# 8  Coimbatore             68
# 9   Allahabad             68

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="2.0.4"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">  <span style='color:#D2BA9E'>|</span> Restaurantes</div>

# %% [markdown]
# <a id="524"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1. <span style='color:#1F2E55'> Qual o nome do restaurante que possui a maior quantidade de avaliações?</span></b>

# %%
# Estou ordenando a coluna restaurant_id do menor para o maior, pois a regra de negócio diz que
# quando o nº de avaliações empatarem nos restaurantes, devo pegar o restaurante de menor ID, ou seja
# o restaurante mais antigo do dataset

cols = [
    'restaurant_id', 'restaurant_name', 'country', 
    'city', 'cuisines', 'aggregate_rating', 'votes'
]

df2.loc[:, cols].sort_values(['votes', 'restaurant_id'], ascending=[False, True]).iloc[0, 1]
# Out:
# 'Bawarchi'

# %%
cols = [
    'restaurant_id', 'restaurant_name', 'country', 
    'city', 'cuisines', 'aggregate_rating', 'votes'
]

df2.loc[:, cols].sort_values(['votes', 'restaurant_id'], ascending=[False, True]).head(10)
# Out:
#       restaurant_id                 restaurant_name country          city  \
# 3928          90896                        Bawarchi   India     Hyderabad
# 3038          58882     Byg Brewski Brewing Company   India     Bangalore
# 2986          51705                            Toit   India     Bangalore
# 3002          51040                        Truffles   India     Bangalore
# 5076         308322                Hauz Khas Social   India     New Delhi
# 3018          56618       AB's - Absolute Barbecues   India     Bangalore
# 5567          91662                        Paradise   India  Secunderabad
# 3879       18207447  Shah Ghouse Hotel & Restaurant   India     Hyderabad
# 4355          20404                       Peter Cat   India       Kolkata
# 3006          54162                 The Black Pearl   India     Bangalore
#
#           cuisines  aggregate_rating  votes
# 3928       Biryani             4.500  41333
# 3038   Continental             4.900  17394
# ...

# %%
( df2.loc[:, ['restaurant_id','restaurant_name','country','votes']]
                                    .sort_values(['votes', 'restaurant_id'], ascending=[False, True])
                                    .head(10) )
# Out:
#       restaurant_id                 restaurant_name country  votes
# 3928          90896                        Bawarchi   India  41333
# 3038          58882     Byg Brewski Brewing Company   India  17394
# 2986          51705                            Toit   India  15270
# 3002          51040                        Truffles   India  14984
# 5076         308322                Hauz Khas Social   India  13627
# 3018          56618       AB's - Absolute Barbecues   India  12443
# 5567          91662                        Paradise   India  11910
# 3879       18207447  Shah Ghouse Hotel & Restaurant   India  11836
# 4355          20404                       Peter Cat   India  11476
# 3006          54162                 The Black Pearl   India  10892

# %%
df2.loc[ df2['votes'] == 41333, ['restaurant_id','restaurant_name','votes'] ]
# Out:
#       restaurant_id restaurant_name  votes
# 3928          90896        Bawarchi  41333

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="525"></a>
# ## <b style="color:#D2BA9E; font-size:80%">2. <span style='color:#1F2E55'> Qual o nome do restaurante com a maior nota média?</span></b>

# %%
( df2.loc[:, ['restaurant_id','restaurant_name', 'aggregate_rating']]
                                .sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                .reset_index()
                                .iloc[0,2] )
# Out:
# 'Indian Grill Room'

# %%
( df2.loc[:, ['restaurant_id','restaurant_name', 'country','aggregate_rating']]
                                .sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                .head(10))
# Out:
#       restaurant_id                 restaurant_name       country  \
# 3766           7528               Indian Grill Room         India
# 3758           8913                Pirates of Grill         India
# 5408          10021                         Darshan         India
# 4362          20842                 Barbeque Nation         India
# 3018          56618       AB's - Absolute Barbecues         India
# 3038          58882     Byg Brewski Brewing Company         India
# 3369          70856       AB's - Absolute Barbecues         India
# 7224          75989  Restaurant Mosaic @ The Orient  South Africa
# 4037         101212                   Tapri Central         India
# 2683         111826                  Yanki Sizzlers         India
#
#       aggregate_rating
# 3766             4.900
# 3758             4.900
# 5408             4.900
# 4362             4.900
# 3018             4.900
# 3038             4.900
# 3369             4.900
# 7224             4.900
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="526"></a>
# ## <b style="color:#D2BA9E; font-size:80%">3. <span style='color:#1F2E55'> Qual o nome do restaurante que possui o maior valor de uma prato para duas pessoas?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','average_cost_for_two']

( df2.loc[: , cols].sort_values(['average_cost_for_two','restaurant_id'], ascending=[False, True])
                                                                        .reset_index().iloc[0,2] )
# Out:
# "d'Arry's Verandah Restaurant"

# %%
cols = ['restaurant_id','restaurant_name','country','average_cost_for_two']

( df2.loc[: , cols].sort_values(['average_cost_for_two','restaurant_id'], ascending=[False, True])
                                                                        .head(10) )
# Out:
#       restaurant_id               restaurant_name    country  \
# 385        16608070  d'Arry's Verandah Restaurant  Australia
# 6049        7403667        The Café - Hotel Mulia  Indonesia
# 6086        7423164          GIA Restaurant & Bar  Indonesia
# 6044        7402935                          SKYE  Indonesia
# 6056        7425027           Shabu-Shabu Shaburi  Indonesia
# 6072        7403002                         Union  Indonesia
# 6046        7422751                    Union Deli  Indonesia
# 6091       18407143                          Gioi  Indonesia
# 6074        7420899                    Sushi Masa  Indonesia
# 6092       17977526                   Holy Smokes  Indonesia
#
#       average_cost_for_two
# 385               25000017
# 6049               1200000
# 6086                700000
# 6044                600000
# 6056                600000
# 6072                550000
# 6046                550000
# 6091                550000
# 6074                500000
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="527"></a>
# ## <b style="color:#D2BA9E; font-size:80%">4. <span style='color:#1F2E55'> Qual o nome do restaurante de tipo de culinária brasileira que possui a menor média de avaliação?</span></b>

# %%
cols = ['restaurant_id', 'restaurant_name','country','aggregate_rating','cuisines']

( df2.loc[ df2['cuisines'] == 'Brazilian', cols]
                        .sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                        .reset_index() 
                        .iloc[0,2] )
# Out:
# 'Loca Como tu Madre'

# %%
cols = ['restaurant_id', 'restaurant_name','country','aggregate_rating','cuisines']

( df2.loc[ df2['cuisines'] == 'Brazilian', cols]
                        .sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                        .head(10) )
# Out:
#      restaurant_id             restaurant_name country  aggregate_rating  \
# 126        6600100          Loca Como tu Madre  Brazil             0.000
# 105        6600119                 Café Savana  Brazil             0.000
# 125        6600124          Inácia Poulet Rôti  Brazil             0.000
# 151        6600456        Galeteria Beira Lago  Brazil             0.000
# 129        6601251                    Severina  Brazil             0.000
# 165        6601325            Capricho Mineiro  Brazil             0.000
# 167        6601525      Restaurante dos Amigos  Brazil             0.000
# 166        6601894  NAVE MÃE FAST FOOD GOURMET  Brazil             0.000
# 333        6703762                     Barbosa  Brazil             0.000
# 319        6706836            Famiglia Rivitti  Brazil             0.000
#
#       cuisines
# 126  Brazilian
# 105  Brazilian
# 125  Brazilian
# 151  Brazilian
# 129  Brazilian
# 165  Brazilian
# 167  Brazilian
# 166  Brazilian
# 333  Brazilian
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="528"></a>
# ## <b style="color:#D2BA9E; font-size:80%">5. <span style='color:#1F2E55'> Qual o nome do restaurante de tipo de culinária brasileira, e que é do Brasil, que possui a maior média de avaliação?</span></b>

# %%
cols = [
    'restaurant_id', 'restaurant_name', 'country', 
    'city', 'cuisines', 'average_cost_for_two', 
    'aggregate_rating', 'votes'
]

lines = (df2['country'] == 'Brazil') & (df2['cuisines'] == 'Brazilian')

df2.loc[lines, cols].sort_values(['aggregate_rating', 'restaurant_id'], ascending=[False, True]).iloc[0, 1]
# Out:
# 'Braseiro da Gávea'

# %%
cols = [
    'restaurant_id', 'restaurant_name', 'country', 
    'city', 'cuisines', 'average_cost_for_two', 
    'aggregate_rating', 'votes'
]

lines = (df2['country'] == 'Brazil') & (df2['cuisines'] == 'Brazilian')

df2.loc[lines, cols].sort_values(['aggregate_rating', 'restaurant_id'], ascending=[False, True]).head(10)
# Out:
#      restaurant_id       restaurant_name country            city   cuisines  \
# 207        7300955     Braseiro da Gávea  Brazil  Rio de Janeiro  Brazilian
# 254        7302898             Aprazível  Brazil  Rio de Janeiro  Brazilian
# 346        6709740                Mocotó  Brazil       São Paulo  Brazilian
# 215        7300515     Garota de Ipanema  Brazil  Rio de Janeiro  Brazilian
# 179        7301525          Fogo de Chão  Brazil  Rio de Janeiro  Brazilian
# 217        7300483  Zazá Bistrô Tropical  Brazil  Rio de Janeiro  Brazilian
# 261        7302859     Aconchego Carioca  Brazil  Rio de Janeiro  Brazilian
# 347        6703176                Veloso  Brazil       São Paulo  Brazilian
# 213        7300521            Balada Mix  Brazil  Rio de Janeiro  Brazilian
# 345        6709580        Esquina Mocotó  Brazil       São Paulo  Brazilian
#
#      average_cost_for_two  aggregate_rating  votes
# 207                   100             4.900     47
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="529"></a>
# ## <b style="color:#D2BA9E; font-size:80%">6. <span style='color:#1F2E55'> Os restaurantes que aceitam pedido online são também, na média, os restaurantes que mais possuem avaliações registradas?</span></b>

# %%
( df2.loc[:, ['votes','has_online_delivery']].groupby('has_online_delivery')
                                           .mean()
                                           .sort_values('votes', ascending=False)
                                           .reset_index() )
# Out:
#    has_online_delivery   votes
# 0                    1 838.822
# 1                    0 479.421

# %% [markdown]
# Sim, conforme mostrado na tabela acima os restaurantes que aceitam pedidos online na média possuem maior quantidade de avaliações

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="530"></a>
# ## <b style="color:#D2BA9E; font-size:80%">7. <span style='color:#1F2E55'> Os restaurantes que fazem reservas são também, na média, os restaurantes que possuem o maior valor médio de um prato para duas pessoas?</span></b>

# %%
( df2.loc[:, ['average_cost_for_two','has_table_booking']]
                        .groupby('has_table_booking')
                        .mean()
                        .sort_values('average_cost_for_two', ascending=False)
                        .reset_index() )
# Out:
#    has_table_booking  average_cost_for_two
# 0                  1             69998.424
# 1                  0              3488.597

# %% [markdown]
# Sim, os restaurantes que fazem reservas possuem na média um maior valor médio no prato para duas pessoas.

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="531"></a>
# ## <b style="color:#D2BA9E; font-size:80%">8. <span style='color:#1F2E55'> Os restaurantes do tipo de culinária japonesa dos Estados Unidos da América possuem um valor médio de prato para duas pessoas maior que as churrascarias americanas (BBQ)?</span></b>

# %%
cols = ['country','cuisines','average_cost_for_two']

lines = (df2['country'] == 'United States of America') & (df2['cuisines'] == 'Japanese')

df2.loc[lines, cols].groupby('cuisines').mean().reset_index()
# Out:
# /tmp/ipykernel_126519/2293839546.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2.loc[lines, cols].groupby('cuisines').mean().reset_index()
#    cuisines  average_cost_for_two
# 0  Japanese                56.406

# %%
cols = ['country','cuisines','average_cost_for_two']

lines = (df2['country'] == 'United States of America') & (df2['cuisines'] == 'BBQ')

df2.loc[lines, cols].groupby('cuisines').mean().reset_index()
# Out:
# /tmp/ipykernel_126519/387829239.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2.loc[lines, cols].groupby('cuisines').mean().reset_index()
#   cuisines  average_cost_for_two
# 0      BBQ                39.643

# %% [markdown]
# Sim, conforme mostrado nas tabelas

# %%
# Outra maneira de solucionar a pergunta
lines = (df2['country'] == 'United States of America') & ((df2['cuisines'] == 'BBQ') | (df2['cuisines'] == 'Japanese'))

(df2.loc[lines, ['average_cost_for_two', 'cuisines'] ]
                                         .groupby('cuisines')
                                         .mean()
                                         .sort_values('average_cost_for_two', ascending=False)
                                         .reset_index())
# Out:
#    cuisines  average_cost_for_two
# 0  Japanese                56.406
# 1       BBQ                39.643

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="2.0.5"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">  <span style='color:#D2BA9E'>|</span> Tipos de Culinária</div>

# %% [markdown]
# <a id="532"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do restaurante com a maior média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Italian'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'Darshan'

# %%
cols = ['restaurant_id','restaurant_name','country','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Italian'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .head(20))
# Out:
#       restaurant_id                       restaurant_name  \
# 5408          10021                               Darshan
# 7233        6501298                 Cafe Del Sol Classico
# 6305        7100171                                 Ombra
# 6574        7700796                              Celino's
# 366        16587684          Andre's Cucina & Polenta Bar
# 1535       16663419              Di Rienzo Grocery & Deli
# 800        16733182  Chicago Pizza & Oven Grinder Company
# 593        16797555                       Regina Pizzeria
# 1241       16831684                         Bottega Louie
# 1280       16923457        Perricone's Marketplace & Café
# 946        16967195                            Big Bill's
# 969        16973071                         Osteria Marco
# 1697       17030960                   The Parlor Pizzeria
# 1805       17156258               Cerroni's Purple Garlic
# 1819       17156955                           Guillermo's
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="533"></a>
# ## <b style="color:#D2BA9E; font-size:80%">2. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária italiana, qual o nome do restaurante com a menor média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Italian'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'Avenida Paulista'

# %%
cols = ['restaurant_id','restaurant_name','country','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Italian'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index()
                                                                     .head(10))
# Out:
#    index  restaurant_id            restaurant_name                   country  \
# 0    150        6600542           Avenida Paulista                    Brazil
# 1    305        6714499               Ristorantino                    Brazil
# 2    324        6715707                        Più                    Brazil
# 3   6723        6800666    Le Delicatezze Di Bruno                   England
# 4    242        7304910  Bene - Sheraton Rio Hotel                    Brazil
# 5    184       18334183   La Bocca Bar e Trattoria                    Brazil
# 6   6752       18756343          The Pasta Factory                   England
# 7   6748       18756659                      Veeno                   England
# 8   1587       16596386                    Siena's                 Australia
# 9   2137       18373064                RPM Italian  United States of America
#
#   cuisines  aggregate_rating
# 0  Italian             0.000
# 1  Italian             0.000
# 2  Italian             0.000
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="534"></a>
# ## <b style="color:#D2BA9E; font-size:80%">3. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária americana, qual o nome do restaurante com a maior média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'American'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'Burger & Lobster'

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'American'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .reset_index()
                                                                     .head(30) )
# Out:
#     index  restaurant_id                    restaurant_name  cuisines  \
# 0    6648        6102616                   Burger & Lobster  American
# 1    6760        6801374                             Solita  American
# 2     726       16631515                  OEB Breakfast Co.  American
# 3     822       16737455                Portillo's Hot Dogs  American
# 4    1460       16776778                              S'MAC  American
# 5    1469       16777384                        Shake Shack  American
# 6    1479       16782050                    5 Napkin Burger  American
# 7    1500       16783153                        Shake Shack  American
# 8    1480       16785398                        Shake Shack  American
# 9     599       16799018                            Fat Cat  American
# 10   1081       16879586                     Barnaby's Cafe  American
# 11   1083       16882572                   Lankford Grocery  American
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="535"></a>
# ## <b style="color:#D2BA9E; font-size:80%">4. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária americana, qual o nome do restaurante com a menor média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'American'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'Alston Bar & Beef'

# %%
cols = ['restaurant_id','restaurant_name','country','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'American'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index()
                                                                     .head(10) )
# Out:
#    index  restaurant_id            restaurant_name               country  \
# 0   6751       18756337          Alston Bar & Beef               England
# 1   7204       18445965  Guy Fieri's Kitchen & Bar          South Africa
# 2    251        7303748                      Bob's                Brazil
# 3   7261        6502573             Hard Rock Cafe          South Africa
# 4   6348        7100971           Thunderbird Cafe            New Zeland
# 5   2407       16541324                    Chili's  United Arab Emirates
# 6   2408       18245065                   O'Learys  United Arab Emirates
# 7   2385       18692865                Lava Lounge  United Arab Emirates
# 8    161        6601283         Capital Steakhouse                Brazil
# 9   6759       18253075                Yard & Coop               England
#
#    cuisines  aggregate_rating
# 0  American             0.000
# 1  American             2.200
# 2  American             2.600
# 3  American             2.800
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="536"></a>
# ## <b style="color:#D2BA9E; font-size:80%">5. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do restaurante com a maior média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Arabian'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'Mandi@36'

# %%
cols = ['restaurant_id','restaurant_name','country','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Arabian'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .reset_index()
                                                                     .head(10))
# Out:
#    index  restaurant_id     restaurant_name               country cuisines  \
# 0   3896       18535007            Mandi@36                 India  Arabian
# 1   2452        5600517  Madfoon Al Khaimah  United Arab Emirates  Arabian
# 2   6883        6200166         Wok of Fame                 Qatar  Arabian
# 3   3184       18770281         Three Kings                 India  Arabian
# 4   2303         201824      Aroos Damascus  United Arab Emirates  Arabian
# 5   2496        5601340      Aroos Damascus  United Arab Emirates  Arabian
# 6   2350         209723           Azkadenya  United Arab Emirates  Arabian
# 7   2243       18427358           Azkadenya  United Arab Emirates  Arabian
# 8   2356         207265               Awani  United Arab Emirates  Arabian
# 9   4249         902109   Sheba Kuzhimandhi                 India  Arabian
#
#    aggregate_rating
# 0             4.700
# 1             4.500
# 2             4.500
# 3             4.500
# 4             4.400
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="537"></a>
# ## <b style="color:#D2BA9E; font-size:80%">6. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária árabe, qual o nome do restaurante com a menor média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Arabian'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'Raful'

# %%
cols = ['restaurant_id','restaurant_name','country','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Arabian'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index()
                                                                     .head(10) )
# Out:
#    index  restaurant_id                   restaurant_name  \
# 0    337        6706513                             Raful
# 1    169        6601535                     Empório Árabe
# 2    147        6600547                      Salim Sou Eu
# 3   5155       18698592                         V Empire
# 4   5118       18698769                  Abad Hot Chicken
# 5   2424       16540460    Murjan - Nour Arjaan by Rotana
# 6   2400       16541428                       Bon Appetit
# 7    115        6600939                           Libanus
# 8   2427       16540483      Breeze - Radisson Blu Resort
# 9   2426       16540485  Al Nokhada - Radisson Blu Resort
#
#                 country cuisines  aggregate_rating
# 0                Brazil  Arabian             0.000
# 1                Brazil  Arabian             2.700
# 2                Brazil  Arabian             3.100
# 3                 India  Arabian             3.200
# 4                 India  Arabian             3.200
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="538"></a>
# ## <b style="color:#D2BA9E; font-size:80%">7. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do restaurante com a maior média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Japanese'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'Sushi Samba'

# %%
cols = ['restaurant_id','restaurant_name','country','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Japanese'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .reset_index()
                                                                     .head(20))
# Out:
#     index  restaurant_id           restaurant_name                   country  \
# 0    6633        6107336               Sushi Samba                   England
# 1    6659        6116563              Chotto Matte                   England
# 2      32        6309831            Ramen Yushoken               Philippines
# 3      17        6316125         Mendokoro Ramenba               Philippines
# 4      21        6318506                      Ooma               Philippines
# 5     240        7300004              Sushi Leblon                    Brazil
# 6    1567       16598168                Nobu Perth                 Australia
# 7    1297       16924138                   Samurai  United States of America
# 8    1020       16989399                Noble Fish  United States of America
# 9    6037       18266425   Gyu - Kaku Japanese BBQ                 Indonesia
# 10   6064       18370724   Gyu - Kaku Japanese BBQ                 Indonesia
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="539"></a>
# ## <b style="color:#D2BA9E; font-size:80%">8. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária japonesa, qual o nome do restaurante com a menor média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Japanese'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'Banzai Sushi'

# %%
cols = ['restaurant_id','restaurant_name','country','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Japanese'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index()
                                                                     .head(10) )
# Out:
#    index  restaurant_id   restaurant_name country  cuisines  aggregate_rating
# 0    123        6600203      Banzai Sushi  Brazil  Japanese             0.000
# 1    181        7300930         Orienthai  Brazil  Japanese             2.400
# 2    182        7304077           Hachiko  Brazil  Japanese             2.500
# 3    112        6600314              Haná  Brazil  Japanese             2.700
# 4    116        6600379        Sushi Loko  Brazil  Japanese             2.900
# 5     95        6600319    Nazo Sushi Bar  Brazil  Japanese             3.200
# 6    113        6600968             Kojma  Brazil  Japanese             3.400
# 7    145        6601143              Soho  Brazil  Japanese             3.600
# 8    132        6601606  Mormaii Surf Bar  Brazil  Japanese             3.600
# 9    158        6601623            Kojima  Brazil  Japanese             3.600

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="540"></a>
# ## <b style="color:#D2BA9E; font-size:80%">9. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do restaurante com a maior média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Home-made'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'Kanaat Lokantası'

# %%
cols = ['restaurant_id','restaurant_name','country','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Home-made'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[False, True])
                                                                     .reset_index() )
# Out:
#    index  restaurant_id      restaurant_name country   cuisines  \
# 0   7525        5914190     Kanaat Lokantası  Turkey  Home-made
# 1   7373        6007184  GurMekan Restaurant  Turkey  Home-made
#
#    aggregate_rating
# 0             4.000
# 1             3.700

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="541"></a>
# ## <b style="color:#D2BA9E; font-size:80%">10. <span style='color:#1F2E55'> Dos restaurantes que possuem o tipo de culinária caseira, qual o nome do restaurante com a menor média de avaliação?</span></b>

# %%
cols = ['restaurant_id','restaurant_name','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Home-made'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index()
                                                                     .iloc[0,2] )
# Out:
# 'GurMekan Restaurant'

# %%
cols = ['restaurant_id','restaurant_name','country','cuisines','aggregate_rating']

lines = df2['cuisines'] == 'Home-made'

( df2.loc[lines, cols].sort_values(['aggregate_rating','restaurant_id'], ascending=[True, True])
                                                                     .reset_index() )
# Out:
#    index  restaurant_id      restaurant_name country   cuisines  \
# 0   7373        6007184  GurMekan Restaurant  Turkey  Home-made
# 1   7525        5914190     Kanaat Lokantası  Turkey  Home-made
#
#    aggregate_rating
# 0             3.700
# 1             4.000

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="542"></a>
# ## <b style="color:#D2BA9E; font-size:80%">11. <span style='color:#1F2E55'> Qual o tipo de culinária que possui o maior valor médio de um prato para duas pessoas?</span></b>

# %%
( df2.loc[:, ['average_cost_for_two','cuisines']].groupby('cuisines')
                                               .max()
                                               .sort_values('average_cost_for_two', ascending=False)
                                               .reset_index()
                                               .iloc[0,0] )
# Out:
# 'Modern Australian'

# %%
( df2.loc[:, ['average_cost_for_two','country','cuisines']].groupby('cuisines')
                                               .max()
                                               .sort_values('average_cost_for_two', ascending=False)
                                               .reset_index()
                                               .head(10))
# Out:
#             cuisines  average_cost_for_two                   country
# 0  Modern Australian              25000017                 Australia
# 1              Asian               1200000  United States of America
# 2            Italian                700000  United States of America
# 3           Japanese                600000  United States of America
# 4            Western                550000                 Indonesia
# 5              Grill                500000              South Africa
# 6              Sushi                500000  United States of America
# 7             German                450000  United States of America
# 8            Spanish                400000  United States of America
# 9               Cafe                300000  United States of America

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="543"></a>
# ## <b style="color:#D2BA9E; font-size:80%">12. <span style='color:#1F2E55'> Qual o tipo de culinária que possui a maior nota média?</span></b>

# %%
( df2.loc[:, ['aggregate_rating','cuisines']].groupby('cuisines')
                                           .max()
                                           .sort_values('aggregate_rating', ascending=False)
                                           .reset_index()
                                           .iloc[0,0] )
# Out:
# 'Indian'

# %%
( df2.loc[:, ['aggregate_rating','cuisines']].groupby('cuisines')
                                           .max()
                                           .sort_values('aggregate_rating', ascending=False)
                                           .reset_index()
                                           .head(1) )
# Out:
#   cuisines  aggregate_rating
# 0   Indian             4.900

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="544"></a>
# ## <b style="color:#D2BA9E; font-size:80%">13. <span style='color:#1F2E55'> Qual o tipo de culinária que possui mais restaurantes que aceitam pedidos online e fazem entregas?</span></b>

# %%
cols = ['restaurant_id','cuisines','has_online_delivery','is_delivering_now','country','city']

lines = (df2['has_online_delivery'] == 1) & (df2['is_delivering_now'] == 1)

( df2.loc[lines, cols].groupby('cuisines').count()
                                        .sort_values('restaurant_id', ascending=False)
                                        .reset_index()
                                        .iloc[0,0] )
# Out:
# 'North Indian'

# %%
# Outra forma de fazer
lines = (df2['has_online_delivery'] == 1) & (df2['is_delivering_now'] == 1)

(df2.loc[:, ['restaurant_id','cuisines'] ]
                                         .groupby('cuisines')
                                         .count()
                                         .sort_values('restaurant_id', ascending=False)
                                         .reset_index()).head(1)
# Out:
#        cuisines  restaurant_id
# 0  North Indian            878

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="004"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">3.0  <span style='color:#D2BA9E'>|</span> Mapas</div>

# %%
df_aux = df2.loc[:, ['cuisines','city','restaurant_name','average_cost_for_two','currency','aggregate_rating','color_name','latitude','longitude']].groupby(['city','cuisines']).median().reset_index()

map = folium.Map()

for index, location_info in df_aux.iterrows():
    folium.Marker(
    [
        location_info['latitude'],
        location_info['longitude']
    ],
    popup = location_info[['city','cuisines']]).add_to(map )

map
# Out:
# /tmp/ipykernel_126519/2766968797.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_aux = df2.loc[:, ['cuisines','city','restaurant_name','average_cost_for_two','currency','aggregate_rating','color_name','latitude','longitude']].groupby(['city','cuisines']).median().reset_index()
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
# ...

# %%
# Código par o Streamlit App para criação do mapa agrupado 

#def create_map(dataframe):
#    f = folium.Figure(width=1920, height=1080)
#
#    m = folium.Map(max_bounds=True).add_to(f)
#
#    marker_cluster = MarkerCluster().add_to(m)
#
#    for _, line in dataframe.iterrows():
#
#        name = line["restaurant_name"]
#        price_for_two = line["average_cost_for_two"]
#        cuisine = line["cuisines"]
#        currency = line["currency"]
#        rating = line["aggregate_rating"]
#        color = f'{line["color_name"]}'
#
#        html = "<p><strong>{}</strong></p>"
#        html += "<p>Price: {},00 ({}) para dois"
#        html += "<br />Type: {}"
#        html += "<br />Aggragate Rating: {}/5.0"
#        html = html.format(name, price_for_two, currency, cuisine, rating)
#
#        popup = folium.Popup(
#            folium.Html(html, script=True),
#            max_width=500,
#        )
#
#        folium.Marker(
#            [line["latitude"], line["longitude"]],
#            popup=popup,
#            icon=folium.Icon(color=color, icon="home", prefix="fa"),
#        ).add_to(marker_cluster)
#
#    folium_static(m, width=1024, height=768)

# %%
 # map_df = df2

# %%
# create_map(map_df)

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="005"></a>
# <div style="padding:10px;
#             color:white;
#             margin:10;
#             font-size:170%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#1F2E55;
#             overflow:hidden;
#             font-weight:700">4.0  <span style='color:#D2BA9E'>|</span> Gráficos</div>

# %% [markdown]
# <a id="545"></a>
# ## <b style="color:#D2BA9E; font-size:80%">1. <span style='color:#1F2E55'> Quantidade de Restaurantes registrados por País</span></b>

# %%
cols = ['restaurant_id','country']

aux = df2.loc[:, cols].groupby('country').nunique().reset_index()

fig = px.bar(aux, x='country', 
                  y='restaurant_id', 
                  labels={'country': 'País', 'restaurant_id': 'Qtde Restaurantes'}, 
                  color='country')

fig.show()
# Out:
# <div>                            <div id="5002b6f6-bf35-4460-8f90-95fa0e77bc23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5002b6f6-bf35-4460-8f90-95fa0e77bc23")) {                    Plotly.newPlot(                        "5002b6f6-bf35-4460-8f90-95fa0e77bc23",                        [{"alignmentgroup":"True","hovertemplate":"Pa\u00eds=%{x}<br>Qtde Restaurantes=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[180],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pa\u00eds=%{x}<br>Qtde Restaurantes=%{y}<extra></extra>","legendgroup":"Brazil"
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="546"></a>
# ## <b style="color:#D2BA9E; font-size:80%">2. <span style='color:#1F2E55'> Quantidade de Cidades Registradas por País</span></b>

# %%
cols = ['city','country']

aux = df2.loc[:, cols].groupby('country').nunique().reset_index()

fig = px.bar(aux, x='country', 
                  y='city', 
                  labels={'country': 'País', 'city': 'Cidade'}, 
                  color='country')

fig.show()
# Out:
# <div>                            <div id="7082c823-e54c-45e2-a8d2-27cf9b30a3cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7082c823-e54c-45e2-a8d2-27cf9b30a3cc")) {                    Plotly.newPlot(                        "7082c823-e54c-45e2-a8d2-27cf9b30a3cc",                        [{"alignmentgroup":"True","hovertemplate":"Pa\u00eds=%{x}<br>Cidade=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pa\u00eds=%{x}<br>Cidade=%{y}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#EF5
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="547"></a>
# ## <b style="color:#D2BA9E; font-size:80%">3. <span style='color:#1F2E55'> Média de Avaliações por País</span></b>

# %%
cols = ['votes','country']

aux = df2.loc[:, cols].groupby('country').mean().reset_index()

fig = px.bar(aux, x='country', y='votes', color='country', labels={'country':'País', 'votes':'Média Avaliação'})

fig.show()
# Out:
# <div>                            <div id="008d32bf-c14f-4d76-940a-da1ce0ab941d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("008d32bf-c14f-4d76-940a-da1ce0ab941d")) {                    Plotly.newPlot(                        "008d32bf-c14f-4d76-940a-da1ce0ab941d",                        [{"alignmentgroup":"True","hovertemplate":"Pa\u00eds=%{x}<br>M\u00e9dia Avalia\u00e7\u00e3o=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[724.2055555555555],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pa\u00eds=%{x}<br>M\u00e9dia Avalia\u00e7\u00e3o=%{y
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="548"></a>
# ## <b style="color:#D2BA9E; font-size:80%">4. <span style='color:#1F2E55'> Média de Preço de um prato para duas pessoas por País</span></b>

# %%
cols = ['average_cost_for_two','country']

aux = df2.loc[:, cols].groupby('country').mean().reset_index()

fig = px.bar(aux, 
             x='country', 
             y='average_cost_for_two', 
             labels={'country':'País', 'average_cost_for_two':'Média de Preço de um prato para duas pessoas'}, 
             color='country')

fig.show()
# Out:
# <div>                            <div id="6ba200ce-0c8c-4294-93fb-3710fb7851e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ba200ce-0c8c-4294-93fb-3710fb7851e2")) {                    Plotly.newPlot(                        "6ba200ce-0c8c-4294-93fb-3710fb7851e2",                        [{"alignmentgroup":"True","hovertemplate":"Pa\u00eds=%{x}<br>M\u00e9dia de Pre\u00e7o de um prato para duas pessoas=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia"],"xaxis":"x","y":[138959.78333333333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Pa\u00eds=%{x}<br>M\u00e9di
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>

# %% [markdown]
# <a id="549"></a>
# ## <b style="color:#D2BA9E; font-size:80%">5. <span style='color:#1F2E55'> Média de Notas para os restaurantes</span></b>

# %%
cols = ['aggregate_rating', 'country']

aux= df2.loc[:, cols].groupby('country').mean().reset_index()

fig = px.scatter(aux, 
           x='country', 
           y='aggregate_rating', 
           color='country', 
           labels={'country':'País','aggregate_rating':'Média da Nota do Restaurante'} )

fig.show()
# Out:
# <div>                            <div id="9d41008f-f770-46d2-8851-7d2cb81d3024" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d41008f-f770-46d2-8851-7d2cb81d3024")) {                    Plotly.newPlot(                        "9d41008f-f770-46d2-8851-7d2cb81d3024",                        [{"hovertemplate":"Pa\u00eds=%{x}<br>M\u00e9dia da Nota do Restaurante=%{y}<extra></extra>","legendgroup":"Australia","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[4.372777777777778],"yaxis":"y","type":"scatter"},{"hovertemplate":"Pa\u00eds=%{x}<br>M\u00e9dia da Nota do Restaurante=%{y}<extra></extra>","legendgroup":"Brazil","marker":{"color":"#EF553B","symb
# ...

# %% [markdown]
# <a href="#000" role="button" aria-pressed="true" >🚀 Voltar para Índice</a>
